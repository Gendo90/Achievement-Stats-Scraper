# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
import datetime
import pandas as pd
import lxml

# %%
#gets alt tags for images that are otherwise given in table as NaN, for levels and country
def getAlt(x):
    for img in x.find_all('img'):
        if(img.get("alt")):
#             print(img.get("alt"))
            img.string = img.get("alt")

#copied code from scrape_mars.py
def getLeaderboardData(lowest_rank):
    url = "https://achievementstats.com/index.php?action=rankings"

    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=False)

    browser.visit(url)
    
    #add a delay so page fully loads
    time.sleep(6)
    
    
    #start collecting data
    
#     for i in range(lowest_rank//30 + 2): #200000//30+2
    curr_rank = int(browser.find_by_tag('tr').last.find_by_tag("td").first.text)
    while(curr_rank < lowest_rank):
        
        try:
            current_leaderboard = browser.html

            news_soup = bs(current_leaderboard, "html.parser")

            top_scorers = news_soup.find_all("table")[0]
#             print(top_scorers.prettify())
            getAlt(top_scorers)

            #if(i == 0):
            #else:
                #output = output.append(pd.read_html(top_scorers.prettify(), header=0, flavor="bs4")[0], ignore_index=True)
            curr_rank = int(browser.find_by_tag('tr').last.find_by_tag("td").first.text)
            print(curr_rank, lowest_rank)
            browser.find_by_tag('tr').last.click()
        except:
#             print("Missing page #{} of 100".format(i))
            print("Error loading, try again!")
        
        time.sleep(1)
        
    time.sleep(10)
    #read output at the end, only once!
    output = pd.read_html(top_scorers.prettify(), header=0, flavor="bs4")[0]
    
    browser.quit()

    return output

# %%
#note that it currently takes about a day to get to ~10000
output_df = getLeaderboardData(300)
output_df
# Out:
# 30 300
# 60 300
# 90 300
# 90 300
# 90 300
# 120 300
# 120 300
# 120 300
# 150 300
# 150 300
# 150 300
# 180 300
# 180 300
# 180 300
# 210 300
# 210 300
# 210 300
# 240 300
# 240 300
# 270 300
# 270 300
# 270 300
# 300 300
#      Rank                  Player                Player.1  \
# 0       1            The Stranger            The Stranger
# 1       2                   lylat                   lylat
# 2       3                  hannez                  hannez
# 3       4                  Skaery                  Skaery
# 4       5                 marklar                 marklar
# ..    ...                     ...                     ...
# 295   296                     WJF                     WJF
# 296   297  EuroCremlin - reMaster  EuroCremlin - reMaster
# 297   298           .oscilloscopa           .oscilloscopa
# 298   299               Tierblume               Tierblume
# 299   300          XKXXK.FX | RUS          XKXXK.FX | RUS
#
#                                      Best achievements     Points       #  \
# 0    First Blood - Part Two  Rambo III  Excessive f...  126734.47  149789
# 1    Arid Finale  CAR vs. Car  Lock, Stock And Barr...  114598.04  137734
# 2    EP1: Communiqué  EP2: Communiqué  EP2: Data Co...   90395.42   94543
# 3    Paddy Locky Fulfillment  World of Easy Goo  Wo...   85915.03   94918
# 4    Tracked Gold  Sitting Duck Gold  Riding Shotgu...   81993.24   84147
# ..                                                 ...        ...     ...
# 295  Arc This Triumph!  Godzilla Tribute  Soul Crus...   18688.31   20723
# 296  Eagle Meister  Midas Touch  Challenge Master  ...   18679.82   18510
# 297  Sgt. MacReady  Patron Saint of Res  Trust No-o...   18639.57   20396
# 298  Challenge King  The Scintillating Flame  The R...   18629.63   16129
# 299  Persistent Perfectionist  Gladiator III  Gladi...   18626.77   15959
#
#      Games  100%                 All  Badges       XP Member since    Hours  \
# 0    16256  4322               20808    4909  3086878   04/15/2011  68006.9
# 1    17202  5718               26428     194   295930   06/03/2009  53803.9
# 2    12977  3828               23006    2008   791705   06/23/2010  27948.5
# 3    10195  2100               13143     644   198801   06/08/2004  88054.4
# 4    11711  3956  No games available    1212   378057   05/01/2008  57020.6
# ..     ...   ...                 ...     ...      ...          ...      ...
# 295   4066   463                4961     292    58156   02/02/2014  10502.3
# 296   2017   426                2374     129    55825   06/23/2012  18074.9
# 297   4390   510                6472     240    39691   06/11/2005  14274.3
# 298   1691   616                2137    1121   129281   03/07/2008   6780.4
# 299    575   283                 740      26     6236   09/23/2015   2695.9
#
#              Last update
# 0    02/26/2022 00:51:18
# 1    02/22/2022 12:08:07
# 2    02/26/2022 21:38:53
# 3    02/22/2022 12:03:24
# 4    02/26/2022 00:39:03
# ..                   ...
# 295  10/31/2021 19:33:41
# 296  11/01/2021 14:45:14
# 297  09/13/2020 21:06:36
# 298  02/24/2022 06:19:11
# 299  04/30/2022 21:36:04
#
# [300 rows x 14 columns]

# %%
output_df.to_csv("example.csv", index=False)

# %%
# TODO - add a larger dataset using this scraping method (~3000 players?)
# TODO - add a better method of retrieving data from the api directly, without going on the webpage (because it takes too long!)
    # Note that the above TODO will need to parse the text responses from the ranking API, probably using regex
