# %%
import time
import datetime
import pandas as pd
import lxml
import json
import requests
import re
from bs4 import BeautifulSoup as bs
from splinter import Browser

# %%
# get start of table using splinter and pandas
# API not working for initial rankings

# %%
# setup basic starter variables
base_url = "https://achievementstats.com/index.php?action=rankings&startRank=1&orderBy=&offset=30"

test_response = requests.get(base_url)
example = test_response.json()
json.dumps(example, indent=4, sort_keys=True)
# Out:
# '[\n    "   <tr>\\r\\n    <td>31</td>\\r\\n    <td><a href=\\"index.php?action=profile&amp;playerId=76561198194198531\\"><img src=\\"images/avatars/76561198194198531.jpg\\" alt=\\"Mike Agresso\\" class=\\"achievementSmall\\" /></a></td>\\r\\n    <td><a href=\\"index.php?action=profile&amp;playerId=76561198194198531\\">Mike Agresso</a></td>\\r\\n    <td style=\\"white-space:nowrap;\\"><a href=\\"index.php?action=games&amp;achievementId=56795\\"><img src=\\"images/icons/unlocked/56795.jpg\\" alt=\\"Seriously. Wow. Just...wow.\\" title=\\"Seriously. Wow. Just...wow. (Procyon &ndash; 3.13 points)\\" class=\\"achievementSmall\\" /></a><a href=\\"index.php?action=games&amp;achievementId=56794\\"><img src=\\"images/icons/unlocked/56794.jpg\\" alt=\\"Still Alive\\" title=\\"Still Alive (Procyon &ndash; 3.03 points)\\" class=\\"achievementSmall\\" /></a><a href=\\"index.php?action=games&amp;achievementId=181660\\"><img src=\\"images/icons/unlocked/181660.jpg\\" alt=\\"Third world\\" title=\\"
# ...

# %%
len(example)
# Out:
# 30

# %%
example[1] = re.sub(r"\<a href\=.*playerId\=(\d+).*?(?=</td>)", r"\1", example[1], 1)
example[1]
# Out:
# '   <tr>\r\n    <td>32</td>\r\n    <td>76561198033967307</td>\r\n    <td><a href="index.php?action=profile&amp;playerId=76561198033967307">DarkTerminator</a></td>\r\n    <td style="white-space:nowrap;"><a href="index.php?action=games&amp;achievementId=3733749"><img src="images/icons/unlocked/3733749.jpg" alt="Three Prongs of Trishula" title="Three Prongs of Trishula (SMITE &ndash; 3.18 points)" class="achievementSmall" /></a><a href="index.php?action=games&amp;achievementId=3733750"><img src="images/icons/unlocked/3733750.jpg" alt="Dance of Bliss and Destruction" title="Dance of Bliss and Destruction (SMITE &ndash; 3.05 points)" class="achievementSmall" /></a><a href="index.php?action=games&amp;achievementId=153591"><img src="images/icons/unlocked/153591.jpg" alt="Don&#039;t Stop Now" title="Don&#039;t Stop Now (Stop Online - Battle of Words &ndash; 2.84 points)" class="achievementSmall" /></a><a href="index.php?action=games&amp;achievementId=3746915"><img src="images/icons/unlocked/
# ...

# %%
example[1] = re.sub(r"<a href=.*?\.jpg\" alt=\".*?\" title=\"(.+?)\".*?</a>", r"\1 \n", example[1])
example[1]
# Out:
# '   <tr>\r\n    <td>32</td>\r\n    <td>76561198033967307</td>\r\n    <td><a href="index.php?action=profile&amp;playerId=76561198033967307">DarkTerminator</a></td>\r\n    <td style="white-space:nowrap;">Three Prongs of Trishula (SMITE &ndash; 3.18 points) \nDance of Bliss and Destruction (SMITE &ndash; 3.05 points) \nDon&#039;t Stop Now (Stop Online - Battle of Words &ndash; 2.84 points) \nExploit: true recursion (Bitburner &ndash; 2.64 points) \nJump Scare (SMITE &ndash; 2.62 points) \nAre you Burdened? (SMITE &ndash; 2.57 points) \nExploit: rainbow (Bitburner &ndash; 2.54 points) \nOrbital Cannon (SMITE &ndash; 2.52 points) \n</td>\r\n    <td style="text-align:right;">36434.12</td>\r\n    <td style="text-align:right;">48251</td>\r\n    <td style="text-align:right;">10622</td>\r\n    <td style="text-align:right;">1598</td>\r\n    <td style="text-align:right;">15284</td>\r\n    <td style="text-align:right;">2548</td>\r\n    <td style="text-align:right;">639989</td>\r\n    <td style="t
# ...

# %%
val = pd.read_html("<table>" + example[1] + "</table>")
val
# Out:
# [   0                  1               2   \
#  0  32  76561198033967307  DarkTerminator
#
#                                                    3         4      5      6   \
#  0  Three Prongs of Trishula (SMITE – 3.18 points)...  36434.12  48251  10622
#
#       7      8     9       10          11       12                   13
#  0  1598  15284  2548  639989  11/22/2010  16359.1  03/29/2022 20:24:36  ]

# %%
print(val[0][3][0])
# Out:
# Three Prongs of Trishula (SMITE – 3.18 points) Dance of Bliss and Destruction (SMITE – 3.05 points) Don't Stop Now (Stop Online - Battle of Words – 2.84 points) Exploit: true recursion (Bitburner – 2.64 points) Jump Scare (SMITE – 2.62 points) Are you Burdened? (SMITE – 2.57 points) Exploit: rainbow (Bitburner – 2.54 points) Orbital Cannon (SMITE – 2.52 points)

# %%
test = re.split(r"(?<=\)) ", val[0][3][0])
test
# Out:
# ['Three Prongs of Trishula (SMITE – 3.18 points)',
#  'Dance of Bliss and Destruction (SMITE – 3.05 points)',
#  "Don't Stop Now (Stop Online - Battle of Words – 2.84 points)",
#  'Exploit: true recursion (Bitburner – 2.64 points)',
#  'Jump Scare (SMITE – 2.62 points)',
#  'Are you Burdened? (SMITE – 2.57 points)',
#  'Exploit: rainbow (Bitburner – 2.54 points)',
#  'Orbital Cannon (SMITE – 2.52 points)']

# %%
val[0][3][0] = test
val
# Out:
# C:\Users\patri\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# [   0                  1               2   \
#  0  32  76561198033967307  DarkTerminator
#
#                                                    3         4      5      6   \
#  0  [Three Prongs of Trishula (SMITE – 3.18 points...  36434.12  48251  10622
#
#       7      8     9       10          11       12                   13
#  0  1598  15284  2548  639989  11/22/2010  16359.1  03/29/2022 20:24:36  ]

# %%
val[0][3][0]
# Out:
# ['Three Prongs of Trishula (SMITE – 3.18 points)',
#  'Dance of Bliss and Destruction (SMITE – 3.05 points)',
#  "Don't Stop Now (Stop Online - Battle of Words – 2.84 points)",
#  'Exploit: true recursion (Bitburner – 2.64 points)',
#  'Jump Scare (SMITE – 2.62 points)',
#  'Are you Burdened? (SMITE – 2.57 points)',
#  'Exploit: rainbow (Bitburner – 2.54 points)',
#  'Orbital Cannon (SMITE – 2.52 points)']

# %%
# setup scraper

def getLeaderboardStandings(max_position, curr_rank=30):
    cols = ["Rank", "Player Id", "Player Name", "Best achievements","Points","#","Games","100%", "All", "Badges", "XP", "Member since","Hours", "Last update"]
    base_url = "https://achievementstats.com/index.php?action=rankings&startRank=1&orderBy=&offset={}"
    
    base_df = pd.DataFrame(columns=cols)
    
    while(curr_rank < max_position):

        test_response = requests.get(base_url.format(curr_rank))
        results = test_response.json()
        size = len(results)
        
        # fix response formatting to work with pandas read_html
        for i in range(size):
            #replace player profile picture with player id
            results[i] = re.sub(r"\<a href\=.*playerId\=(\d+).*?(?=</td>)", r"\1", results[i], 1)
            #replace best achievements pictures with text
            results[i] = re.sub(r"<a href=.*?\.jpg\" alt=\".*?\" title=\"(.+?)\".*?</a>", r"\1 \n", results[i])
            
        # concatenate rows
        starter_table = ""
        for player in results:
            starter_table += player
            
        # read in as a table
        table_snapshot = pd.read_html("<table>" + starter_table + "</table>")
        
        for i in range(size):
            curr_ach = table_snapshot[0][3][i]
            try:
                curr_ach = re.split(r"(?<=\)) ", curr_ach)
                table_snapshot[0][3][i] = curr_ach
            except:
                continue
            
        table_snapshot[0].columns = cols
        base_df = base_df.append(table_snapshot)
        curr_rank += size
        print(curr_rank)
        
    return base_df

# %%
cols = ["Rank", "Player Id", "Player Name", "Best achievements","Points","#","Games","100%", "All Badges", "XP", "Member since","Hours", "Last update"]

example_df = pd.DataFrame(columns=cols)
example_df
# Out:
# Empty DataFrame
# Columns: [Rank, Player Id, Player Name, Best achievements, Points, #, Games, 100%, All Badges, XP, Member since, Hours, Last update]
# Index: []

# %%
# test scraper
test_scraper_df = getLeaderboardStandings(100000)
test_scraper_df
# Out:
# C:\Users\patri\anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 60
# C:\Users\patri\anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 90
# C:\Users\patri\anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 120
# ...

# %%
#should have the first 100k players!
len(test_scraper_df.index)
# Out:
# 99990

# %%
test_scraper_df.to_csv("./first100kplayers.csv", index=False)

# %%
# test scraper
test_scraper_df_2 = getLeaderboardStandings(200000, 100020)
test_scraper_df_2
# Out:
# C:\Users\patri\anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100050
# C:\Users\patri\anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100080
# C:\Users\patri\anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100110
# ...

# %%
test_scraper_df_2.tail(5)
# Out:
#       Rank          Player Id Player Name  \
# 25  200006  76561198054283364     Citadel
# 26  200007  76561197969699674        Lum_
# 27  200008  76561198052777604     Aqualad
# 28  200009  76561198016103169      sjjklh
# 29  200010  76561198085756286    Krizelit
#
#                                     Best achievements  Points    # Games 100%  \
# 25  [Catfish Master (Fishing Planet – 2.06 points)...  399.19  802   142    2
# 26  [The Boot (Expeditions: Conquistador – 1.74 po...  399.19  719   202    2
# 27  [We're going to need a bigger razor (Jack Lumb...  399.19  737   146    1
# 28  [Gold Assassin (Company of Heroes 2 – 1.61 poi...  399.19  826   156    2
# 29  [Arcade S-license (Crazy Taxi – 1.38 points), ...  399.19  927   467    4
#
#       All Badges     XP Member since   Hours          Last update
# 25  205.0      8   1936   12/10/2011  3386.7  12/25/2021 05:11:57
# 26    NaN      4   1579   10/19/2004  1636.9  05/15/2019 06:48:06
# ...

# %%
test_scraper_df_2.to_csv("./first200kplayers.csv", index=False)

# %%
all_200k_df = test_scraper_df.append(test_scraper_df_2)
all_200k_df
# Out:
#       Rank          Player Id     Player Name  \
# 0       31  76561198194198531    Mike Agresso
# 1       32  76561198033967307  DarkTerminator
# 2       33  76561198056523764           Hanni
# 3       34  76561198138702126        𝖟𝖍𝖎𝖙𝖍𝖊𝖆𝖉
# 4       35  76561198027973295   Ghost Patriot
# ..     ...                ...             ...
# 25  200006  76561198054283364         Citadel
# 26  200007  76561197969699674            Lum_
# 27  200008  76561198052777604         Aqualad
# 28  200009  76561198016103169          sjjklh
# 29  200010  76561198085756286        Krizelit
#
#                                     Best achievements    Points      #  Games  \
# 0   [Seriously. Wow. Just...wow. (Procyon – 3.13 p...  36791.65  26840   2142
# 1   [Three Prongs of Trishula (SMITE – 3.18 points...  36434.12  48251  10622
# 2   [Timing is your friend (Half-Past Impossible –...  36339.11  44742  11170
# 3   [You have become death (The Superfluous – 2.81...  36254.32  28890   1348
# ...

# %%
all_200k_df.to_csv("./all_first_200k.csv", index=False)

# %%
# TODO: must add initial 30 players (top rankings!) - not available from the API initially, need to scrape webpage
# TODO: must add country data, also scraped from webpage

# %%
temp_axes = all_200k_df.plot(kind="scatter", x="Hours", 
                                       y="Rank", 
                                       title="Rank vs. Hours")

# %%
temp_axes2 = all_200k_df.plot(kind="scatter", x="Hours", 
                                       y="Points", 
                                       title="Points vs. Hours")

# %%
temp_axes3 = all_200k_df.plot(kind="scatter", x="Hours", 
                                       y="Games", 
                                       title="Games vs. Hours")

# %%
temp_axes4 = all_200k_df.plot(kind="scatter", x="Hours", 
                                       y="XP", 
                                       title="XP vs. Hours")

# %%
temp_axes5 = all_200k_df.plot(kind="scatter", x="Hours", 
                                       y="Badges", 
                                       title="Badges vs. Hours")
